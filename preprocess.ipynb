# %% [markdown]
# # 데이터 불러오기

# %%
import pandas as pd
import sqlite3 as sql

path = 'c:/data/football/database.sqlite'
conn = sql.connect(path)

# %%
sql_master_tables = pd.read_sql('select * from sqlite_master where type="table";', conn)
sql_master_tables
# Out:
#     type               name           tbl_name  rootpage  \
# 0  table    sqlite_sequence    sqlite_sequence         4
# 1  table  Player_Attributes  Player_Attributes        11
# 2  table             Player             Player        14
# 3  table              Match              Match        18
# 4  table             League             League        24
# 5  table            Country            Country        26
# 6  table               Team               Team        29
# 7  table    Team_Attributes    Team_Attributes         2
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "Player_Attributes" (\n\t`id`\tIN...
# 2  CREATE TABLE `Player` (\n\t`id`\tINTEGER PRIMA...
# 3  CREATE TABLE `Match` (\n\t`id`\tINTEGER PRIMAR...
# 4  CREATE TABLE `League` (\n\t`id`\tINTEGER PRIMA...
# 5  CREATE TABLE `Country` (\n\t`id`\tINTEGER PRIM...
# 6  CREATE TABLE "Team" (\n\t`id`\tINTEGER PRIMARY...
# ...

# %%
# 선수 속성 및 선수 능력치 데이터 합치기
df = pd.read_sql('''select p.player_name, p.*, pa.* 
                from Player_Attributes as pa
                inner join Player as p
                on pa.player_api_id = p.player_api_id;''', conn)

pd.set_option('display.max_columns', None) # 모든 컬럼 표시
df.head()
# Out:
#           player_name  id  player_api_id         player_name  \
# 0  Aaron Appindangoye   1         505942  Aaron Appindangoye
# 1  Aaron Appindangoye   1         505942  Aaron Appindangoye
# 2  Aaron Appindangoye   1         505942  Aaron Appindangoye
# 3  Aaron Appindangoye   1         505942  Aaron Appindangoye
# 4  Aaron Appindangoye   1         505942  Aaron Appindangoye
#
#    player_fifa_api_id             birthday  height  weight  id  \
# 0              218353  1992-02-29 00:00:00  182.88     187   1
# 1              218353  1992-02-29 00:00:00  182.88     187   2
# 2              218353  1992-02-29 00:00:00  182.88     187   3
# 3              218353  1992-02-29 00:00:00  182.88     187   4
# 4              218353  1992-02-29 00:00:00  182.88     187   5
#
#    player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0              218353         505942  2016-02-18 00:00:00            67.0
# ...

# %%
df.shape
# Out:
# (183978, 50)

# %%
# 데이터 프레임을 csv로 저장
df.to_csv("./csv/data.csv", index=None)

# %% [markdown]
# # 데이터 전처리

# %%
df = pd.read_csv('./csv/data.csv', index_col=None)
df.head()
# Out:
#           player_name  id  player_api_id       player_name.1  \
# 0  Aaron Appindangoye   1         505942  Aaron Appindangoye
# 1  Aaron Appindangoye   1         505942  Aaron Appindangoye
# 2  Aaron Appindangoye   1         505942  Aaron Appindangoye
# 3  Aaron Appindangoye   1         505942  Aaron Appindangoye
# 4  Aaron Appindangoye   1         505942  Aaron Appindangoye
#
#    player_fifa_api_id             birthday  height  weight  id.1  \
# 0              218353  1992-02-29 00:00:00  182.88     187     1
# 1              218353  1992-02-29 00:00:00  182.88     187     2
# 2              218353  1992-02-29 00:00:00  182.88     187     3
# 3              218353  1992-02-29 00:00:00  182.88     187     4
# 4              218353  1992-02-29 00:00:00  182.88     187     5
#
#    player_fifa_api_id.1  player_api_id.1                 date  overall_rating  \
# 0                218353           505942  2016-02-18 00:00:00            67.0
# ...

# %%
df.shape
# Out:
# (183978, 50)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183978 entries, 0 to 183977
# Data columns (total 50 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   player_name           183978 non-null  object
#  1   id                    183978 non-null  int64
#  2   player_api_id         183978 non-null  int64
#  3   player_name.1         183978 non-null  object
#  4   player_fifa_api_id    183978 non-null  int64
#  5   birthday              183978 non-null  object
#  6   height                183978 non-null  float64
#  7   weight                183978 non-null  int64
#  8   id.1                  183978 non-null  int64
#  9   player_fifa_api_id.1  183978 non-null  int64
#  10  player_api_id.1       183978 non-null  int64
#  11  date                  183978 non-null  object
#  12  overall_rating        183142 non-null  float64
#  13  potential             183142 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['player_name', 'id', 'player_api_id', 'player_name.1',
#        'player_fifa_api_id', 'birthday', 'height', 'weight', 'id.1',
#        'player_fifa_api_id.1', 'player_api_id.1', 'date', 'overall_rating',
#        'potential', 'preferred_foot', 'attacking_work_rate',
#        'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
#        'gk_reflexes'],
#       dtype='object')

# %%
# 불필요한 컬럼 제거
df.drop(['player_name', 'id', 'player_api_id', 'player_name.1', 'player_fifa_api_id', 'birthday', 'height', 'weight', 'id.1', 'player_fifa_api_id.1', 'player_api_id.1', 'date'], axis=1, inplace=True)
df.head()
# Out:
#    overall_rating  potential preferred_foot attacking_work_rate  \
# 0            67.0       71.0          right              medium
# 1            67.0       71.0          right              medium
# 2            62.0       66.0          right              medium
# 3            61.0       65.0          right              medium
# 4            61.0       65.0          right              medium
#
#   defensive_work_rate  crossing  finishing  heading_accuracy  short_passing  \
# 0              medium      49.0       44.0              71.0           61.0
# 1              medium      49.0       44.0              71.0           61.0
# 2              medium      49.0       44.0              71.0           61.0
# 3              medium      48.0       43.0              70.0           60.0
# 4              medium      48.0       43.0              70.0           60.0
#
#    volleys  dribbling  curve  free_kick_accuracy  long_passing  ball_control  \
# ...

# %%
df.columns
# Out:
# Index(['overall_rating', 'potential', 'preferred_foot', 'attacking_work_rate',
#        'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
#        'gk_reflexes'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# overall_rating          836
# potential               836
# preferred_foot          836
# attacking_work_rate    3230
# defensive_work_rate     836
# crossing                836
# finishing               836
# heading_accuracy        836
# short_passing           836
# volleys                2713
# dribbling               836
# curve                  2713
# free_kick_accuracy      836
# long_passing            836
# ball_control            836
# acceleration            836
# sprint_speed            836
# agility                2713
# reactions               836
# balance                2713
# shot_power              836
# jumping                2713
# stamina                 836
# strength                836
# long_shots              836
# aggression              836
# interceptions           836
# positioning             836
# vision                 2713
# penalties               836
# marking                 836
# standing_tackle         836
# sliding_tackle         2713
# ...

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# overall_rating         0
# potential              0
# preferred_foot         0
# attacking_work_rate    0
# defensive_work_rate    0
# crossing               0
# finishing              0
# heading_accuracy       0
# short_passing          0
# volleys                0
# dribbling              0
# curve                  0
# free_kick_accuracy     0
# long_passing           0
# ball_control           0
# acceleration           0
# sprint_speed           0
# agility                0
# reactions              0
# balance                0
# shot_power             0
# jumping                0
# stamina                0
# strength               0
# long_shots             0
# aggression             0
# interceptions          0
# positioning            0
# vision                 0
# penalties              0
# marking                0
# standing_tackle        0
# sliding_tackle         0
# gk_diving              0
# gk_handling            0
# gk_kicking             0
# gk_positioning         0
# ...

# %%
df.shape
# Out:
# (180354, 38)

# %%
df.dtypes
# Out:
# overall_rating         float64
# potential              float64
# preferred_foot          object
# attacking_work_rate     object
# defensive_work_rate     object
# crossing               float64
# finishing              float64
# heading_accuracy       float64
# short_passing          float64
# volleys                float64
# dribbling              float64
# curve                  float64
# free_kick_accuracy     float64
# long_passing           float64
# ball_control           float64
# acceleration           float64
# sprint_speed           float64
# agility                float64
# reactions              float64
# balance                float64
# shot_power             float64
# jumping                float64
# stamina                float64
# strength               float64
# long_shots             float64
# aggression             float64
# interceptions          float64
# positioning            float64
# vision                 float64
# penalties              float64
# ...

# %%
df['preferred_foot'].unique()
# Out:
# array(['right', 'left'], dtype=object)

# %%
df = pd.concat([df, (pd.get_dummies(df['preferred_foot'], prefix="preferred_foot"))], axis=1)
df.head()
# Out:
#    overall_rating  potential preferred_foot attacking_work_rate  \
# 0            67.0       71.0          right              medium
# 1            67.0       71.0          right              medium
# 2            62.0       66.0          right              medium
# 3            61.0       65.0          right              medium
# 4            61.0       65.0          right              medium
#
#   defensive_work_rate  crossing  finishing  heading_accuracy  short_passing  \
# 0              medium      49.0       44.0              71.0           61.0
# 1              medium      49.0       44.0              71.0           61.0
# 2              medium      49.0       44.0              71.0           61.0
# 3              medium      48.0       43.0              70.0           60.0
# 4              medium      48.0       43.0              70.0           60.0
#
#    volleys  dribbling  curve  free_kick_accuracy  long_passing  ball_control  \
# ...

# %%
df['attacking_work_rate'].unique()
# Out:
# array(['medium', 'high', 'low', 'None', 'le', 'norm', 'stoc', 'y'],
#       dtype=object)

# %%
df['defensive_work_rate'].unique()
# Out:
# array(['medium', 'high', 'low', '5', 'ean', 'o', '1', 'ormal', '7', '2',
#        '8', '4', 'tocky', '0', '3', '6', '9', 'es'], dtype=object)

# %%
df.drop(['attacking_work_rate', 'defensive_work_rate', 'preferred_foot'], axis=1, inplace=True)

# %%
df
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0                 67.0       71.0      49.0       44.0              71.0
# 1                 67.0       71.0      49.0       44.0              71.0
# 2                 62.0       66.0      49.0       44.0              71.0
# 3                 61.0       65.0      48.0       43.0              70.0
# 4                 61.0       65.0      48.0       43.0              70.0
# ...                ...        ...       ...        ...               ...
# 183973            83.0       85.0      84.0       77.0              59.0
# 183974            78.0       80.0      74.0       76.0              53.0
# 183975            77.0       80.0      74.0       71.0              53.0
# 183976            78.0       81.0      74.0       64.0              57.0
# 183977            80.0       81.0      74.0       68.0              57.0
#
#         short_passing  volleys  dribbling  curve  free_kick_accuracy  \
# ...

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

df["gk_handling"].hist()
plt.xlabel('gk_handling')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

df["gk_diving"].hist()
plt.xlabel('gk_diving')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
df1 = df[df['gk_diving'] <= 20]
df1.head()
# Out:
#    overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0            67.0       71.0      49.0       44.0              71.0
# 1            67.0       71.0      49.0       44.0              71.0
# 2            62.0       66.0      49.0       44.0              71.0
# 3            61.0       65.0      48.0       43.0              70.0
# 4            61.0       65.0      48.0       43.0              70.0
#
#    short_passing  volleys  dribbling  curve  free_kick_accuracy  long_passing  \
# 0           61.0     44.0       51.0   45.0                39.0          64.0
# 1           61.0     44.0       51.0   45.0                39.0          64.0
# 2           61.0     44.0       51.0   45.0                39.0          64.0
# 3           60.0     43.0       50.0   44.0                38.0          63.0
# 4           60.0     43.0       50.0   44.0                38.0          63.0
#
#    ball_control  acceleration  sprint_speed  agility  reactions  balance  \
# ...

# %%
df1.columns
# Out:
# Index(['overall_rating', 'potential', 'crossing', 'finishing',
#        'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve',
#        'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration',
#        'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power',
#        'jumping', 'stamina', 'strength', 'long_shots', 'aggression',
#        'interceptions', 'positioning', 'vision', 'penalties', 'marking',
#        'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling',
#        'gk_kicking', 'gk_positioning', 'gk_reflexes', 'preferred_foot_left',
#        'preferred_foot_right'],
#       dtype='object')

# %%
df1.drop(['gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes'], axis=1, inplace=True)
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_14148\124207801.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(['gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes'], axis=1, inplace=True)

# %%
df1
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0                 67.0       71.0      49.0       44.0              71.0
# 1                 67.0       71.0      49.0       44.0              71.0
# 2                 62.0       66.0      49.0       44.0              71.0
# 3                 61.0       65.0      48.0       43.0              70.0
# 4                 61.0       65.0      48.0       43.0              70.0
# ...                ...        ...       ...        ...               ...
# 183973            83.0       85.0      84.0       77.0              59.0
# 183974            78.0       80.0      74.0       76.0              53.0
# 183975            77.0       80.0      74.0       71.0              53.0
# 183976            78.0       81.0      74.0       64.0              57.0
# 183977            80.0       81.0      74.0       68.0              57.0
#
#         short_passing  volleys  dribbling  curve  free_kick_accuracy  \
# ...

# %%
# 박스플롯
# %matplotlib inline
df1.boxplot(figsize=(15, 10))
plt.show()

# %%
# 히스토그램
# %matplotlib inline
df1.hist(bins=50, figsize=(15, 15))
plt.show()

# %% [markdown]
# # csv로 변환

# %%
df1.to_csv('./csv/preprocess.csv', index=None)
